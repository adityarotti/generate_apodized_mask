# %%
import healpy as h
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d1=h.read_map("./mask512_fh0a_apo360a.fits")
d2=h.read_map("./mask512_fh0a_apo240a.fits")
d0=h.read_map("../datain/mask512.fits")
# Out:
# NSIDE = 512
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 512
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 512
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
h.mollview(d0)
h.mollview(d1)
h.mollview(d2)
# Out:
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

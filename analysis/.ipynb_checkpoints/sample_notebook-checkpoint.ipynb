# %%
import sys,os

import pymain
import healpy as h
# %pylab notebook
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ef44497b475e> in <module>()
#       1 import sys,os
# ----> 2 import pymain
#       3 import healpy as h
#       4 get_ipython().magic(u'pylab notebook')
#
# ImportError: No module named pymain

# %%
mask=h.read_map("datain/mask512.fits",verbose=False)
nside=h.get_nside(mask)
npixtot=np.size(mask)

# %%
temp=pymain.gen_apodized_mask(mask,nside,1,580.,0.,240.,npixtot)

# %%
h.mollview(temp)
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
pymain.gen_apodized_mask?
